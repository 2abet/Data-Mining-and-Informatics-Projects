# %% [markdown]
# # Workshop 4b - Dudley Hierarchical clustering
#
# ### Student Number: 2302546

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import os, re
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from IPython.display import IFrame
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
 
# %matplotlib inline
 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# For this notebook, I am considering a period of December 2021 to December 2022

# %%
path_to_data = './crime'
cd = os.path.dirname(os.path.abspath(path_to_data))
 
i = 0
columns = range(1,100)
dfList = []
 
for root, dirs, files in os.walk(cd):
    for fname in files:
        if re.match("^.*.csv$", fname):
            frame = pd.read_csv(os.path.join(root, fname))
            frame['key'] = "file{}".format(i)
            dfList.append(frame)    
            i += 1
 
dataset = pd.concat(dfList)

# %%
dataset.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2021-12
# 1  01988dde64ab85a563fdbf7b7d48bb1c64163446defb36...  2021-12
# 2  80a7628f3737fe0f5fe1d3835f44730498309bb28565f2...  2021-12
# 3  5d2ea684f34a8c6ffd574c8a61b326447a3c9384174084...  2021-12
# 4  552eac09561aa50f4c68db0a4c0d11512c80066ea2f55a...  2021-12
#
#             Reported by          Falls within  Longitude   Latitude  \
# 0  West Midlands Police  West Midlands Police  -1.850772  52.588691
# 1  West Midlands Police  West Midlands Police  -1.851382  52.591757
# 2  West Midlands Police  West Midlands Police  -1.851382  52.591757
# 3  West Midlands Police  West Midlands Police  -1.849280  52.593346
# 4  West Midlands Police  West Midlands Police  -1.840641  52.598270
#
#                        Location  LSOA code        LSOA name  \
# 0    On or near Seymour Gardens  E01009417  Birmingham 001A
# 1       On or near Walsall Road  E01009417  Birmingham 001A
# 2       On or near Walsall Road  E01009417  Birmingham 001A
# 3  On or near Russell Bank Road  E01009417  Birmingham 001A
# 4  On or near Badgers Bank Road  E01009418  Birmingham 001B
#
#                      Crime type  \
# 0         Anti-social behaviour
# 1                       Robbery
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4                      Burglary
#
#                            Last outcome category  Context    key
# 0                                            NaN      NaN  file0
# 1  Investigation complete; no suspect identified      NaN  file0
# 2                    Unable to prosecute suspect      NaN  file0
# 3                    Unable to prosecute suspect      NaN  file0
# 4  Investigation complete; no suspect identified      NaN  file0

# %%
print(dataset.shape)
# Out:
# (3765438, 13)

# %%
name_number = 'AkinyemiArabambi-2302546.csv'

# %%
data = pd.read_csv(name_number)

# %%
data['Crime type'].value_counts()
# Out:
# Violence and sexual offences    1073298
# Vehicle crime                    244020
# Public order                     217134
# Criminal damage and arson        192186
# Other theft                      167760
# Burglary                         138522
# Anti-social behaviour            135048
# Shoplifting                      105486
# Robbery                           53544
# Drugs                             51480
# Possession of weapons             45744
# Other crime                       41364
# Theft from the person             29004
# Bicycle theft                     15702
# Name: Crime type, dtype: int64

# %% [markdown]
# # Q1. Use a similar approach to display number of crimes in each month. You can use the "Month" column to do that.

# %%
data['Month'].value_counts()
# Out:
# 2022-07    207492
# 2022-05    204630
# 2022-08    202050
# 2022-06    200004
# 2022-10    197748
# 2022-03    195582
# 2021-12    193224
# 2022-04    191058
# 2022-09    190182
# 2022-01    187698
# 2022-11    185784
# 2022-02    178782
# 2022-12    176058
# Name: Month, dtype: int64

# %%
data['town'] = data['LSOA name'].str.split(' ').str[0]

# %%
data.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2021-12
# 1  01988dde64ab85a563fdbf7b7d48bb1c64163446defb36...  2021-12
# 2  80a7628f3737fe0f5fe1d3835f44730498309bb28565f2...  2021-12
# 3  5d2ea684f34a8c6ffd574c8a61b326447a3c9384174084...  2021-12
# 4  552eac09561aa50f4c68db0a4c0d11512c80066ea2f55a...  2021-12
#
#             Reported by          Falls within  Longitude   Latitude  \
# 0  West Midlands Police  West Midlands Police  -1.850772  52.588691
# 1  West Midlands Police  West Midlands Police  -1.851382  52.591757
# 2  West Midlands Police  West Midlands Police  -1.851382  52.591757
# 3  West Midlands Police  West Midlands Police  -1.849280  52.593346
# 4  West Midlands Police  West Midlands Police  -1.840641  52.598270
#
#                        Location  LSOA code        LSOA name  \
# 0    On or near Seymour Gardens  E01009417  Birmingham 001A
# 1       On or near Walsall Road  E01009417  Birmingham 001A
# 2       On or near Walsall Road  E01009417  Birmingham 001A
# 3  On or near Russell Bank Road  E01009417  Birmingham 001A
# 4  On or near Badgers Bank Road  E01009418  Birmingham 001B
#
#                      Crime type  \
# 0         Anti-social behaviour
# 1                       Robbery
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4                      Burglary
#
#                            Last outcome category  Context    key        town
# 0                                            NaN      NaN  file0  Birmingham
# 1  Investigation complete; no suspect identified      NaN  file0  Birmingham
# 2                    Unable to prosecute suspect      NaN  file0  Birmingham
# 3                    Unable to prosecute suspect      NaN  file0  Birmingham
# 4  Investigation complete; no suspect identified      NaN  file0  Birmingham

# %%
towns = ['Dudley']
filtered_data = data[data.town.str.contains('|'.join(towns), na=False)]
filtered_data.head()
# Out:
#                                                 Crime ID    Month  \
# 17770  4343dfc303951b62cddb34d316f7396ce2fa078906cfa2...  2021-12
# 17771  84b43f3b32d33a4003a8484ca98b141744da5bca25f9d3...  2021-12
# 17772  5034aa50a37e7431c7047ae66ff7eba95c30b5a0fad919...  2021-12
# 17773  cc984934af7be5524dbd1c78f67fdd2fdba189cceb1bf7...  2021-12
# 17774  c084477f818e8e32dffc951f7160649a122dc9de788e04...  2021-12
#
#                 Reported by          Falls within  Longitude   Latitude  \
# 17770  West Midlands Police  West Midlands Police  -2.083943  52.549631
# 17771  West Midlands Police  West Midlands Police  -2.077263  52.550139
# 17772  West Midlands Police  West Midlands Police  -2.087360  52.547390
# 17773  West Midlands Police  West Midlands Police  -2.075000  52.545942
# 17774  West Midlands Police  West Midlands Police  -2.083943  52.549631
#
#                        Location  LSOA code    LSOA name  \
# 17770    On or near Bell Street  E01009763  Dudley 001A
# 17771  On or near Skidmore Road  E01009763  Dudley 001A
# 17772   On or near Havacre Lane  E01009763  Dudley 001A
# 17773  On or near Sunbury Close  E01009763  Dudley 001A
# 17774    On or near Bell Street  E01009763  Dudley 001A
#
#                       Crime type  \
# 17770  Criminal damage and arson
# 17771  Criminal damage and arson
# 17772                Other theft
# 17773                Other theft
# 17774                Other theft
#
#                                Last outcome category  Context    key    town
# 17770  Investigation complete; no suspect identified      NaN  file0  Dudley
# 17771  Investigation complete; no suspect identified      NaN  file0  Dudley
# 17772  Investigation complete; no suspect identified      NaN  file0  Dudley
# 17773  Investigation complete; no suspect identified      NaN  file0  Dudley
# 17774  Investigation complete; no suspect identified      NaN  file0  Dudley

# %% [markdown]
# # Q2. Display crime types in Dudley.

# %%
print('The crime types in Dudley are: ', filtered_data['Crime type'].unique())
# Out:
# The crime types in Dudley are:  ['Criminal damage and arson' 'Other theft' 'Public order' 'Vehicle crime'
#  'Violence and sexual offences' 'Anti-social behaviour' 'Burglary'
#  'Other crime' 'Possession of weapons' 'Robbery' 'Theft from the person'
#  'Shoplifting' 'Drugs' 'Bicycle theft']

# %% [markdown]
# # Q3. What is the most common crime committed in Dudley in the dataset? Is it the same most common crime in West Midlands too?

# %%
filtered_data['Crime type'].value_counts()
# Out:
# Violence and sexual offences    92772
# Vehicle crime                   20178
# Public order                    19320
# Criminal damage and arson       18558
# Anti-social behaviour           11934
# Burglary                        11616
# Other theft                     11244
# Shoplifting                      9762
# Other crime                      4044
# Robbery                          3624
# Possession of weapons            3444
# Drugs                            3078
# Theft from the person            1224
# Bicycle theft                     360
# Name: Crime type, dtype: int64

# %%
data['Crime type'].value_counts()
# Out:
# Violence and sexual offences    1073298
# Vehicle crime                    244020
# Public order                     217134
# Criminal damage and arson        192186
# Other theft                      167760
# Burglary                         138522
# Anti-social behaviour            135048
# Shoplifting                      105486
# Robbery                           53544
# Drugs                             51480
# Possession of weapons             45744
# Other crime                       41364
# Theft from the person             29004
# Bicycle theft                     15702
# Name: Crime type, dtype: int64

# %% [markdown]
# #### Q. Sort the column 'LSOA code' by number of crimes and display the top 10 'LOSA code'.

# %%
filtered_data['LSOA code'].value_counts().nlargest(10)
# Out:
# E01009741    8472
# E01009892    6378
# E01009757    5850
# E01009881    5082
# E01009889    4908
# E01009744    4134
# E01009856    3918
# E01009746    3762
# E01009836    3750
# E01033187    3534
# Name: LSOA code, dtype: int64

# %% [markdown]
# # Q4. Provide a prime landmark of minimum of 2 LSOA codes under investigation. If there is no recognisable prime landmark, provide name(s) of the nearby streets/roads surrounding those areas.
#
# LSOA code E01009741 which is the Merry Hill Shopping Center which includes the area around the Mill Street as well has the highest crime rate of 1412 crimes in Dudley (https://www.doogal.co.uk/LSOA?code=E01009741)
#
# LSOA code E01009892 is the area Dudley Southern bypass which includes Trindle road and St Johns road has the second highest crime rate of 1350 in the Dudley region (https://www.doogal.co.uk/LSOA?code=E01009892)

# %%
filtered_important_data = filtered_data[['LSOA code','Crime type']]
filtered_important_data = pd.get_dummies(filtered_important_data, columns=['Crime type'])
clustering_data = filtered_important_data.groupby(['LSOA code']).agg(
    {'Crime type_Anti-social behaviour':'sum',
     'Crime type_Bicycle theft':'sum',
     'Crime type_Burglary':'sum',
     'Crime type_Criminal damage and arson':'sum',
     'Crime type_Drugs':'sum', 
     'Crime type_Other crime':'sum', 
     'Crime type_Other theft':'sum', 
     'Crime type_Possession of weapons':'sum', 
     'Crime type_Public order':'sum', 
     'Crime type_Robbery':'sum', 
     'Crime type_Shoplifting':'sum', 
     'Crime type_Theft from the person':'sum', 
     'Crime type_Vehicle crime':'sum', 
     'Crime type_Violence and sexual offences':'sum'
    }
    ).reset_index()

# %%
clustering_data[:5]
# Out:
#    LSOA code  Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# 0  E01009719                               6.0                         0
# 1  E01009720                               0.0                         0
# 2  E01009721                             108.0                         6
# 3  E01009722                               6.0                         6
# 4  E01009723                              24.0                         0
#
#    Crime type_Burglary  Crime type_Criminal damage and arson  \
# 0                 24.0                                  36.0
# 1                 36.0                                   6.0
# 2                 78.0                                  84.0
# 3                 48.0                                   6.0
# 4                 18.0                                  18.0
#
#    Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# 0                 0                      18                    12.0
# 1                 0                       0                    18.0
# 2                24                      30                    60.0
# 3                 0                      12                    12.0
# 4                 0                       6                    24.0
#
#    Crime type_Possession of weapons  Crime type_Public order  \
# 0                                 6                     48.0
# 1                                 0                     12.0
# 2                                18                     72.0
# 3                                 0                      6.0
# 4                                12                      6.0
#
#    Crime type_Robbery  Crime type_Shoplifting  \
# 0                 6.0                     0.0
# 1                 0.0                     0.0
# 2                24.0                     6.0
# 3                 6.0                     6.0
# 4                 0.0                   126.0
#
#    Crime type_Theft from the person  Crime type_Vehicle crime  \
# 0                                 0                      36.0
# 1                                 0                      18.0
# 2                                 6                     138.0
# 3                                 6                      36.0
# 4                                 6                      54.0
#
#    Crime type_Violence and sexual offences
# 0                                    276.0
# 1                                     84.0
# 2                                    612.0
# 3                                    126.0
# 4                                     60.0

# %%
clustering_data_original = clustering_data.copy()
clustering_data_original.head()
# Out:
#    LSOA code  Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# 0  E01009719                               6.0                         0
# 1  E01009720                               0.0                         0
# 2  E01009721                             108.0                         6
# 3  E01009722                               6.0                         6
# 4  E01009723                              24.0                         0
#
#    Crime type_Burglary  Crime type_Criminal damage and arson  \
# 0                 24.0                                  36.0
# 1                 36.0                                   6.0
# 2                 78.0                                  84.0
# 3                 48.0                                   6.0
# 4                 18.0                                  18.0
#
#    Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# 0                 0                      18                    12.0
# 1                 0                       0                    18.0
# 2                24                      30                    60.0
# 3                 0                      12                    12.0
# 4                 0                       6                    24.0
#
#    Crime type_Possession of weapons  Crime type_Public order  \
# 0                                 6                     48.0
# 1                                 0                     12.0
# 2                                18                     72.0
# 3                                 0                      6.0
# 4                                12                      6.0
#
#    Crime type_Robbery  Crime type_Shoplifting  \
# 0                 6.0                     0.0
# 1                 0.0                     0.0
# 2                24.0                     6.0
# 3                 6.0                     6.0
# 4                 0.0                   126.0
#
#    Crime type_Theft from the person  Crime type_Vehicle crime  \
# 0                                 0                      36.0
# 1                                 0                      18.0
# 2                                 6                     138.0
# 3                                 6                      36.0
# 4                                 6                      54.0
#
#    Crime type_Violence and sexual offences
# 0                                    276.0
# 1                                     84.0
# 2                                    612.0
# 3                                    126.0
# 4                                     60.0

# %%
clustering_data.drop(['LSOA code'], axis = 1, inplace = True, errors = 'ignore')
clustering_data.head()
# Out:
#    Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# 0                               6.0                         0
# 1                               0.0                         0
# 2                             108.0                         6
# 3                               6.0                         6
# 4                              24.0                         0
#
#    Crime type_Burglary  Crime type_Criminal damage and arson  \
# 0                 24.0                                  36.0
# 1                 36.0                                   6.0
# 2                 78.0                                  84.0
# 3                 48.0                                   6.0
# 4                 18.0                                  18.0
#
#    Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# 0                 0                      18                    12.0
# 1                 0                       0                    18.0
# 2                24                      30                    60.0
# 3                 0                      12                    12.0
# 4                 0                       6                    24.0
#
#    Crime type_Possession of weapons  Crime type_Public order  \
# 0                                 6                     48.0
# 1                                 0                     12.0
# 2                                18                     72.0
# 3                                 0                      6.0
# 4                                12                      6.0
#
#    Crime type_Robbery  Crime type_Shoplifting  \
# 0                 6.0                     0.0
# 1                 0.0                     0.0
# 2                24.0                     6.0
# 3                 6.0                     6.0
# 4                 0.0                   126.0
#
#    Crime type_Theft from the person  Crime type_Vehicle crime  \
# 0                                 0                      36.0
# 1                                 0                      18.0
# 2                                 6                     138.0
# 3                                 6                      36.0
# 4                                 6                      54.0
#
#    Crime type_Violence and sexual offences
# 0                                    276.0
# 1                                     84.0
# 2                                    612.0
# 3                                    126.0
# 4                                     60.0

# %%
data_scaled = normalize(clustering_data)
data_scaled = pd.DataFrame(data_scaled, columns=clustering_data.columns)
data_scaled.head()
# Out:
#    Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# 0                          0.020924                  0.000000
# 1                          0.000000                  0.000000
# 2                          0.164764                  0.009154
# 3                          0.042409                  0.042409
# 4                          0.153506                  0.000000
#
#    Crime type_Burglary  Crime type_Criminal damage and arson  \
# 0             0.083697                              0.125546
# 1             0.375735                              0.062622
# 2             0.118996                              0.128149
# 3             0.339276                              0.042409
# 4             0.115129                              0.115129
#
#    Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# 0          0.000000                0.062773                0.041849
# 1          0.000000                0.000000                0.187867
# 2          0.036614                0.045768                0.091535
# 3          0.000000                0.084819                0.084819
# 4          0.000000                0.038376                0.153506
#
#    Crime type_Possession of weapons  Crime type_Public order  \
# 0                          0.020924                 0.167395
# 1                          0.000000                 0.125245
# 2                          0.027461                 0.109842
# 3                          0.000000                 0.042409
# 4                          0.076753                 0.038376
#
#    Crime type_Robbery  Crime type_Shoplifting  \
# 0            0.020924                0.000000
# 1            0.000000                0.000000
# 2            0.036614                0.009154
# 3            0.042409                0.042409
# 4            0.000000                0.805906
#
#    Crime type_Theft from the person  Crime type_Vehicle crime  \
# 0                          0.000000                  0.125546
# 1                          0.000000                  0.187867
# 2                          0.009154                  0.210531
# 3                          0.042409                  0.254457
# 4                          0.038376                  0.345388
#
#    Crime type_Violence and sexual offences
# 0                                 0.962520
# 1                                 0.876714
# 2                                 0.933660
# 3                                 0.890598
# 4                                 0.383765

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
plt.axhline(y=1.5, color='r', linestyle='--')

# %% [markdown]
# # Q5. Discuss what happens when you decide to cut the dendogram at a different level.

# %% [markdown]
# Cutting a dendrogram at a different level means selecting a different threshold value for the height at which to "cut" the dendrogram to obtain a set number of clusters. When cutting the dendrogram at a lower level in this instance at 1.0 will result in 7 clusters as compared to the current 4 clusters. If it is cut at an higher level say 2.0, the cluster is reduced to 3.
#
# If the dendrogram is cut at a high level, the resulting clusters will be more general and inclusive, meaning that similar data points will be grouped together regardless of their finer differences. This may be appropriate for exploratory data analysis or for identifying broad patterns in the data.
#
# On the other hand, cutting the dendrogram at a low level may result in more specific and granular clusters, which can reveal more subtle patterns in the data. However, if the dendrogram is cut too low, it may result in overfitting or generating clusters that are too specific to the particular data at hand, leading to poor generalization and limited usefulness for future analyses.
#
# Therefore, the decision of where to cut the dendrogram should be made carefully and should consider the specific goals of the analysis and the nature of the data being clustered. It is often helpful to explore the results of clustering at different levels to gain a better understanding of the structure of the data and to choose a suitable level for the final set of clusters.

# %%
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
cluster_ids = cluster.fit_predict(data_scaled)

# %%
clustering_data['cluster'] = cluster_ids
clustering_data.head()
# Out:
#    Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# 0                               6.0                         0
# 1                               0.0                         0
# 2                             108.0                         6
# 3                               6.0                         6
# 4                              24.0                         0
#
#    Crime type_Burglary  Crime type_Criminal damage and arson  \
# 0                 24.0                                  36.0
# 1                 36.0                                   6.0
# 2                 78.0                                  84.0
# 3                 48.0                                   6.0
# 4                 18.0                                  18.0
#
#    Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# 0                 0                      18                    12.0
# 1                 0                       0                    18.0
# 2                24                      30                    60.0
# 3                 0                      12                    12.0
# 4                 0                       6                    24.0
#
#    Crime type_Possession of weapons  Crime type_Public order  \
# 0                                 6                     48.0
# 1                                 0                     12.0
# 2                                18                     72.0
# 3                                 0                      6.0
# 4                                12                      6.0
#
#    Crime type_Robbery  Crime type_Shoplifting  \
# 0                 6.0                     0.0
# 1                 0.0                     0.0
# 2                24.0                     6.0
# 3                 6.0                     6.0
# 4                 0.0                   126.0
#
#    Crime type_Theft from the person  Crime type_Vehicle crime  \
# 0                                 0                      36.0
# 1                                 0                      18.0
# 2                                 6                     138.0
# 3                                 6                      36.0
# 4                                 6                      54.0
#
#    Crime type_Violence and sexual offences  cluster
# 0                                    276.0        1
# 1                                     84.0        2
# 2                                    612.0        1
# 3                                    126.0        2
# 4                                     60.0        0

# %%
hierarchical_cluster = pd.DataFrame(round(clustering_data.groupby('cluster').mean(),1))
hierarchical_cluster
# Out:
#          Crime type_Anti-social behaviour  Crime type_Bicycle theft  \
# cluster
# 0                                   104.3                       3.1
# 1                                    70.2                       2.1
# 2                                    26.7                       0.9
# 3                                    10.4                       0.0
#
#          Crime type_Burglary  Crime type_Criminal damage and arson  \
# cluster
# 0                       65.5                                 115.3
# 1                       60.1                                 118.2
# 2                       49.7                                  40.9
# 3                       57.3                                  24.5
#
#          Crime type_Drugs  Crime type_Other crime  Crime type_Other theft  \
# cluster
# 0                    24.8                    16.2                    86.1
# 1                    18.7                    27.3                    60.6
# 2                     6.0                     9.7                    41.4
# 3                     4.9                     3.8                    14.2
#
#          Crime type_Possession of weapons  Crime type_Public order  \
# cluster
# 0                                    30.8                    144.0
# 1                                    21.3                    116.6
# 2                                     5.1                     45.7
# 3                                     3.8                     26.2
#
#          Crime type_Robbery  Crime type_Shoplifting  \
# cluster
# 0                      44.6                   272.1
# 1                      18.7                    26.3
# 2                       7.8                     9.1
# 3                       4.9                     2.7
#
#          Crime type_Theft from the person  Crime type_Vehicle crime  \
# cluster
# 0                                    19.3                     147.4
# 1                                     6.2                      94.3
# 2                                     1.2                      90.8
# 3                                     0.5                     111.8
#
#          Crime type_Violence and sexual offences
# cluster
# 0                                          530.1
# 1                                          591.5
# 2                                          225.2
# 3                                          110.2

# %% [markdown]
# # Q6. Discuss the clustering results based on your dataset.
# Based on observation, the clustering results can be observed to show that:
# - Cluster ID 0 is the LSOA codes with the highest number of crimes (the highest risk regions).
# - Cluster ID 3 is the LSOA codes with the lowest number of crimes (the lowest risk regions).
# - Cluster ID 1 is the LSOA codes with moderate number of crimes.
# - Cluster ID 2 is the LSOA codes where crime numbers are mild.

# %%
clustering_data_original['cluster'] = cluster_ids
clusters = clustering_data_original[['LSOA code', 'cluster']]

# %%
clusters.head()
# Out:
#    LSOA code  cluster
# 0  E01009719        1
# 1  E01009720        2
# 2  E01009721        1
# 3  E01009722        2
# 4  E01009723        0

# %%
clusters.shape
# Out:
# (201, 2)

# %%
clustered_full = pd.merge(filtered_data, clusters, on='LSOA code')
clustered_full.head()
# Out:
#                                             Crime ID    Month  \
# 0  4343dfc303951b62cddb34d316f7396ce2fa078906cfa2...  2021-12
# 1  84b43f3b32d33a4003a8484ca98b141744da5bca25f9d3...  2021-12
# 2  5034aa50a37e7431c7047ae66ff7eba95c30b5a0fad919...  2021-12
# 3  cc984934af7be5524dbd1c78f67fdd2fdba189cceb1bf7...  2021-12
# 4  c084477f818e8e32dffc951f7160649a122dc9de788e04...  2021-12
#
#             Reported by          Falls within  Longitude   Latitude  \
# 0  West Midlands Police  West Midlands Police  -2.083943  52.549631
# 1  West Midlands Police  West Midlands Police  -2.077263  52.550139
# 2  West Midlands Police  West Midlands Police  -2.087360  52.547390
# 3  West Midlands Police  West Midlands Police  -2.075000  52.545942
# 4  West Midlands Police  West Midlands Police  -2.083943  52.549631
#
#                    Location  LSOA code    LSOA name  \
# 0    On or near Bell Street  E01009763  Dudley 001A
# 1  On or near Skidmore Road  E01009763  Dudley 001A
# 2   On or near Havacre Lane  E01009763  Dudley 001A
# 3  On or near Sunbury Close  E01009763  Dudley 001A
# 4    On or near Bell Street  E01009763  Dudley 001A
#
#                   Crime type                          Last outcome category  \
# 0  Criminal damage and arson  Investigation complete; no suspect identified
# 1  Criminal damage and arson  Investigation complete; no suspect identified
# 2                Other theft  Investigation complete; no suspect identified
# 3                Other theft  Investigation complete; no suspect identified
# 4                Other theft  Investigation complete; no suspect identified
#
#    Context    key    town  cluster
# 0      NaN  file0  Dudley        1
# 1      NaN  file0  Dudley        1
# 2      NaN  file0  Dudley        1
# 3      NaN  file0  Dudley        1
# 4      NaN  file0  Dudley        1

# %%
def get_color(cluster_id):
    if cluster_id == 0:
        return 'darkred'
    if cluster_id == 2:
        return 'green'
    if cluster_id == 3:
        return 'amber'
    if cluster_id == 1:
        return 'blue'

# %%
#create a map
this_map = folium.Map(location =[clustered_full["Latitude"].mean(), 
                                 clustered_full["Longitude"].mean()], zoom_start=5)
 
def plot_dot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.Latitude, point.Longitude],
                        radius=2, 
                        color=point.color,
                        weight=1).add_to(this_map)
    
    
clustered_full["color"] = clustered_full["cluster"].apply(lambda x: get_color(x))
 
#use df.apply(,axis=1) to iterate through every row in your dataframe
clustered_full.apply(plot_dot, axis = 1)
 
 
#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())
 
#Save the map to an HTML file
this_map.save(os.path.join('Crime_map2.html'))
#IFrame(src='Crime_map.html', width=1000, height=600)
